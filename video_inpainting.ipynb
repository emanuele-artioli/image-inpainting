# %%
import cv2
import os
import shutil
import ffmpeg
import numpy as np
import subprocess
from typing import Union
import PIL
from skimage.metrics import structural_similarity as ssim
from skimage.transform import resize
import json
from concurrent.futures import ProcessPoolExecutor

# %%
unprocessed_video_path = 'Tears_of_Steel_1080p.mov'

def get_video_info(video_path):
    # FFprobe command to get specific video information in JSON format
    ffprobe_cmd = [
        'ffprobe', '-v', 'error', '-print_format', 'json', '-show_format',
        '-show_streams', '-select_streams', 'v:0', video_path
    ]

    # Execute FFprobe command and capture output
    result = subprocess.run(ffprobe_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Check if FFprobe command was successful
    if result.returncode != 0:
        print("Error: Failed to execute FFprobe command")
        return None

    # Parse JSON output
    video_info = json.loads(result.stdout)

    # Extract specific information
    info_dict = {
        'codec_name': video_info['streams'][0]['codec_name'],
        'codec_tag_string': video_info['streams'][0]['codec_tag_string'],
        'width': video_info['streams'][0]['width'],
        'height': video_info['streams'][0]['height'],
        'average_frame_rate': video_info['streams'][0]['avg_frame_rate'],
        'duration': video_info['format']['duration'],
        'bit_rate': video_info['format']['bit_rate'],
        'bits_per_raw_sample': video_info['streams'][0].get('bits_per_raw_sample', None),
        'encoder': video_info['streams'][0].get('encoder', None),
        'file_name': video_info['format']['filename'],
        'format_name': video_info['format']['format_name'],
        'size': video_info['format']['size']
    }

    return info_dict

unprocessed_video_info = get_video_info(unprocessed_video_path)
unprocessed_video_info
# Out:
# {'codec_name': 'h264',
#  'codec_tag_string': 'avc1',
#  'width': 1920,
#  'height': 800,
#  'average_frame_rate': '24/1',
#  'duration': '734.166667',
#  'bit_rate': '6361215',
#  'bits_per_raw_sample': '8',
#  'encoder': None,
#  'file_name': 'Tears_of_Steel_1080p.mov',
#  'format_name': 'mov,mp4,m4a,3gp,3g2,mj2',
#  'size': '583774083'}

# %%
# TODO: simplify by using ffmpeg filter scene, also does not save last scene, irrelevant for now but maybe I can fix it
def split_video_into_scenes(video_path: str, threshold: int = 100, output_format: str = 'avi', vcodec: str = 'huffyuv', max_scenes: int = None) -> str:
    """
    Split a video into scenes based on the difference between consecutive frames.

    Args:
    - video_path (str): Path to the input video file.
    - threshold (int): Threshold value for detecting scene changes. Default is 100.
    - output_format (str): Output video format for the scenes. Default is 'avi'.
    - vcodec (str): Video codec for the output videos. Default is 'huffyuv'.
    - max_scenes (int): Maximum number of scenes to extract. Default is None (extract all scenes).

    Returns:
    - str: Path to the folder containing the extracted scenes.

    This function reads a video file frame by frame, calculates the absolute difference between consecutive frames,
    and detects scene changes based on the mean difference exceeding a threshold. It saves each scene as a separate
    video file in a folder named after the input video file.

    """

    # Extract folder path and create the folder if it doesn't exist
    folder_path, _ = video_path.rsplit('.', 1)
    if os.path.exists(folder_path):
        shutil.rmtree(folder_path)
    os.mkdir(folder_path)

    # Open the video file
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    prev_frame = None
    scene_start = 0
    scene_number = 1
    scenes_extracted = 0

    # Parse the video frame by frame
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        if prev_frame is not None:
            # Calculate absolute difference between frames
            diff = cv2.absdiff(prev_frame, frame)
            mean_diff = diff.mean()
            # Detect scene changes based on mean difference exceeding the threshold
            if mean_diff > threshold:
                # Get times of scene start and end, and save new video between those times
                scene_end = cap.get(cv2.CAP_PROP_POS_MSEC)
                # Save scene using ffmpeg
                output_file = os.path.join(folder_path, f"scene_{scene_number}.{output_format}")
                ffmpeg.input(video_path, ss=scene_start/1000, to=scene_end/1000).output(output_file, vcodec=vcodec).run()
                scene_start = scene_end
                scene_number += 1
                scenes_extracted += 1
                if max_scenes is not None and scenes_extracted >= max_scenes:
                    break

        prev_frame = frame.copy()

    cap.release()

    return folder_path

scene_format = 'avi'
scene_codec = 'huffyuv'
max_scenes = 5
scene_similarity_threshold = 45

video_folder = split_video_into_scenes(
    unprocessed_video_path, 
    scene_similarity_threshold, 
    scene_format, 
    scene_codec,
    max_scenes
)
# Out:
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-5)
#   configuration: --prefix=/home/itec/emanuele/.conda/envs/inpainting --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/pkg-config
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'Tears_of_Steel_1080p.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf53.32.100
#   Duration: 00:12:14.17, start: 0.000000, bitrate: 6361 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 1920x800 [SAR 1:1 DAR 12:5], 6162 kb/s, 24 fps, 24 tbr, 24 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : FFMP
#       encoder         : libx264
#   Stream #0:1[0x2](eng): Audio: mp3 (.mp3 / 0x33706D2E), 44100 Hz, stereo, fltp, 191 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> huffyuv (native))
#   Stream #0:1 -> #0:1 (mp3 (mp3float) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [huffyuv @ 0x563b7d73e080] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7d844980] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7d945740] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7d946380] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7da4dbc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7dc60140] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7dd66640] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7de6cf40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7df73840] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7e07a140] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7e180a40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7e287340] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7e38dc40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7e494540] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7e59ae40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7e6a1740] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7e7a8040] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7e8ae940] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7e9b5240] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7eabbb40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7ebc2440] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7ecc8d40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7edcf640] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7eed5f40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7efdc840] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7f0e3140] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7f1e9a40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7f2f0340] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7f3f6c40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7f4fd540] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7f603e40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7f70a740] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7f811040] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7f917940] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7fa1e240] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7fb24b40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7fc2b440] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7fd31d40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7fe38640] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7ff3ef40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b80045840] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b8014c140] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b80252a40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b80359340] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b8045fc40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b80566540] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b8066ce40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b80773740] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b8087a040] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b80980940] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b80a87240] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b80b8db40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b80c94440] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b80d9ad40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b80ea1640] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b80fa7f40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b810ae840] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b811b5140] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b812bba40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b813c2340] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b814c8c40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b815cf540] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b816d5e40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b817dc740] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x563b7c02bd00] using huffyuv 2.2.0 or newer interlacing flag
# Output #0, avi, to 'Tears_of_Steel_1080p/scene_1.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     ISFT            : Lavf60.16.100
#   Stream #0:0(eng): Video: huffyuv (HFYU / 0x55594648), yuv422p(tv, progressive), 1920x800 [SAR 1:1 DAR 12:5], q=2-31, 200 kb/s, 24 fps, 24 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : FFMP
#       encoder         : Lavc60.31.102 huffyuv
#   Stream #0:1(eng): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libmp3lame
# [out#0/avi @ 0x563b7c0324c0] video:161360kB audio:140kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.014220%
# frame=  214 fps=0.0 q=-0.0 Lsize=  161523kB time=00:00:08.90 bitrate=148526.6kbits/s speed=12.1x
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-5)
#   configuration: --prefix=/home/itec/emanuele/.conda/envs/inpainting --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/pkg-config
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'Tears_of_Steel_1080p.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf53.32.100
#   Duration: 00:12:14.17, start: 0.000000, bitrate: 6361 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 1920x800 [SAR 1:1 DAR 12:5], 6162 kb/s, 24 fps, 24 tbr, 24 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : FFMP
#       encoder         : libx264
#   Stream #0:1[0x2](eng): Audio: mp3 (.mp3 / 0x33706D2E), 44100 Hz, stereo, fltp, 191 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> huffyuv (native))
#   Stream #0:1 -> #0:1 (mp3 (mp3float) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [huffyuv @ 0x560455961ac0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560455a682c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560455b69080] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560455b69cc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560455c71500] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560455e83a80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560455f89f80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560456090880] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560456197180] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x56045629da80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604563a4380] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604564aac80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604565b1580] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604566b7e80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604567be780] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604568c5080] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604569cb980] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560456ad2280] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560456bd8b80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560456cdf480] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560456de5d80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560456eec680] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560456ff2f80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604570f9880] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560457200180] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560457306a80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x56045740d380] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560457513c80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x56045761a580] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560457720e80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560457827780] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x56045792e080] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560457a34980] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560457b3b280] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560457c41b80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560457d48480] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560457e4ed80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560457f55680] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x56045805bf80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560458162880] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560458269180] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x56045836fa80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560458476380] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x56045857cc80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560458683580] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560458789e80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560458890780] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560458997080] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560458a9d980] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560458ba4280] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560458caab80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560458db1480] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560458eb7d80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560458fbe680] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604590c4f80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604591cb880] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604592d2180] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604593d8a80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604594df380] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604595e5c80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604596ec580] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604597f2e80] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5604598f9780] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x560459a00080] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x56045424dd00] using huffyuv 2.2.0 or newer interlacing flag
# Output #0, avi, to 'Tears_of_Steel_1080p/scene_2.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     ISFT            : Lavf60.16.100
#   Stream #0:0(eng): Video: huffyuv (HFYU / 0x55594648), yuv422p(tv, progressive), 1920x800 [SAR 1:1 DAR 12:5], q=2-31, 200 kb/s, 24 fps, 24 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : FFMP
#       encoder         : Lavc60.31.102 huffyuv
#   Stream #0:1(eng): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libmp3lame
# [out#0/avi @ 0x5604542544c0] video:113779kB audio:71kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.014546%
# frame=  109 fps=0.0 q=-0.0 Lsize=  113867kB time=00:00:04.52 bitrate=206359.4kbits/s speed=9.21x
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-5)
#   configuration: --prefix=/home/itec/emanuele/.conda/envs/inpainting --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/pkg-config
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'Tears_of_Steel_1080p.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf53.32.100
#   Duration: 00:12:14.17, start: 0.000000, bitrate: 6361 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 1920x800 [SAR 1:1 DAR 12:5], 6162 kb/s, 24 fps, 24 tbr, 24 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : FFMP
#       encoder         : libx264
#   Stream #0:1[0x2](eng): Audio: mp3 (.mp3 / 0x33706D2E), 44100 Hz, stereo, fltp, 191 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> huffyuv (native))
#   Stream #0:1 -> #0:1 (mp3 (mp3float) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [huffyuv @ 0x562dfab1f240] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfac20000] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfac20c40] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfad28480] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfaf3aa00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfb040f00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfb147800] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfb24e100] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfb354a00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfb45b300] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfb561c00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfb668500] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfb76ee00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfb875700] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfb97c000] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfba82900] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfbb89200] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfbc8fb00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfbd96400] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfbe9cd00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfbfa3600] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfc0a9f00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfc1b0800] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfc2b7100] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfc3bda00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfc4c4300] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfc5cac00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfc6d1500] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfc7d7e00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfc8de700] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfc9e5000] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfcaeb900] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfcbf2200] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfccf8b00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfcdff400] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfcf05d00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfd00c600] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfd112f00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfd219800] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfd320100] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfd426a00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfd52d300] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfd633c00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfd73a500] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfd840e00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfd947700] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfda4e000] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfdb54900] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfdc5b200] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfdd61b00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfde68400] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfdf6ed00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfe075600] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfe17bf00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfe282800] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfe389100] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfe48fa00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfe596300] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfe69cc00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfe7a3500] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfe8a9e00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfe9b0700] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfeab7000] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562dfebbd900] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x562df940ad00] using huffyuv 2.2.0 or newer interlacing flag
# Output #0, avi, to 'Tears_of_Steel_1080p/scene_3.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     ISFT            : Lavf60.16.100
#   Stream #0:0(eng): Video: huffyuv (HFYU / 0x55594648), yuv422p(tv, progressive), 1920x800 [SAR 1:1 DAR 12:5], q=2-31, 200 kb/s, 24 fps, 24 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : FFMP
#       encoder         : Lavc60.31.102 huffyuv
#   Stream #0:1(eng): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libmp3lame
# [out#0/avi @ 0x562df94114c0] video:118960kB audio:78kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.014424%
# frame=  119 fps=0.0 q=-0.0 Lsize=  119055kB time=00:00:04.93 bitrate=197500.0kbits/s speed=9.55x
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-5)
#   configuration: --prefix=/home/itec/emanuele/.conda/envs/inpainting --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/pkg-config
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'Tears_of_Steel_1080p.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf53.32.100
#   Duration: 00:12:14.17, start: 0.000000, bitrate: 6361 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 1920x800 [SAR 1:1 DAR 12:5], 6162 kb/s, 24 fps, 24 tbr, 24 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : FFMP
#       encoder         : libx264
#   Stream #0:1[0x2](eng): Audio: mp3 (.mp3 / 0x33706D2E), 44100 Hz, stereo, fltp, 191 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> huffyuv (native))
#   Stream #0:1 -> #0:1 (mp3 (mp3float) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [huffyuv @ 0x55ea64af4400] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea64bfac00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea64d01400] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea64e021c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea64e02e00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea64f0a640] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea6511cbc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea652230c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea653299c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea654302c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea65536bc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea6563d4c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea65743dc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea6584a6c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea65950fc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea65a578c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea65b5e1c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea65c64ac0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea65d6b3c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea65e71cc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea65f785c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea6607eec0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea661857c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea6628c0c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea663929c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea664992c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea6659fbc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea666a64c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea667acdc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea668b36c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea669b9fc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea66ac08c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea66bc71c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea66ccdac0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea66dd43c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea66edacc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea66fe15c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea670e7ec0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea671ee7c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea672f50c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea673fb9c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea675022c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea67608bc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea6770f4c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea67815dc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea6791c6c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea67a22fc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea67b298c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea67c301c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea67d36ac0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea67e3d3c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea67f43cc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea6804a5c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea68150ec0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea682577c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea6835e0c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea684649c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea6856b2c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea68671bc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea687784c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea6887edc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea689856c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea68a8bfc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea68b928c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55ea633dfd00] using huffyuv 2.2.0 or newer interlacing flag
# Output #0, avi, to 'Tears_of_Steel_1080p/scene_4.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     ISFT            : Lavf60.16.100
#   Stream #0:0(eng): Video: huffyuv (HFYU / 0x55594648), yuv422p(tv, progressive), 1920x800 [SAR 1:1 DAR 12:5], q=2-31, 200 kb/s, 24 fps, 24 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : FFMP
#       encoder         : Lavc60.31.102 huffyuv
#   Stream #0:1(eng): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libmp3lame
# [libmp3lame @ 0x55ea6428a600] Trying to remove 1152 samples, but the queue is empty speed=11.5x
# [out#0/avi @ 0x55ea633e64c0] video:165829kB audio:104kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.011790%
# frame=  158 fps=0.0 q=-0.0 Lsize=  165953kB time=00:00:06.58 bitrate=206500.4kbits/s speed=11.1x
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-5)
#   configuration: --prefix=/home/itec/emanuele/.conda/envs/inpainting --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/pkg-config
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'Tears_of_Steel_1080p.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf53.32.100
#   Duration: 00:12:14.17, start: 0.000000, bitrate: 6361 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 1920x800 [SAR 1:1 DAR 12:5], 6162 kb/s, 24 fps, 24 tbr, 24 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : FFMP
#       encoder         : libx264
#   Stream #0:1[0x2](eng): Audio: mp3 (.mp3 / 0x33706D2E), 44100 Hz, stereo, fltp, 191 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> huffyuv (native))
#   Stream #0:1 -> #0:1 (mp3 (mp3float) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [huffyuv @ 0x55858503e300] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558585144b00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55858524b300] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55858534c0c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55858534cd00] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558585454540] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558585666ac0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55858576cfc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585858738c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55858597a1c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558585a80ac0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558585b873c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558585c8dcc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558585d945c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558585e9aec0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558585fa17c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585860a80c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585861ae9c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585862b52c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585863bbbc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585864c24c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585865c8dc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585866cf6c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585867d5fc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585868dc8c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585869e31c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558586ae9ac0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558586bf03c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558586cf6cc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558586dfd5c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558586f03ec0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55858700a7c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585871110c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585872179c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55858731e2c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558587424bc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55858752b4c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558587631dc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585877386c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55858783efc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585879458c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558587a4c1c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558587b52ac0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558587c593c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558587d5fcc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558587e665c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558587f6cec0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585880737c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55858817a0c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585882809c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585883872c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55858848dbc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585885944c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x55858869adc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585887a16c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585888a7fc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585889ae8c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558588ab51c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558588bbbac0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558588cc23c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558588dc8cc0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558588ecf5c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558588fd5ec0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x5585890dc7c0] using huffyuv 2.2.0 or newer interlacing flag
# [huffyuv @ 0x558583929d00] using huffyuv 2.2.0 or newer interlacing flag
# Output #0, avi, to 'Tears_of_Steel_1080p/scene_5.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     ISFT            : Lavf60.16.100
#   Stream #0:0(eng): Video: huffyuv (HFYU / 0x55594648), yuv422p(tv, progressive), 1920x800 [SAR 1:1 DAR 12:5], q=2-31, 200 kb/s, 24 fps, 24 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : FFMP
#       encoder         : Lavc60.31.102 huffyuv
#   Stream #0:1(eng): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libmp3lame
# [out#0/avi @ 0x5585839304c0] video:415956kB audio:239kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.007739%
# frame=  366 fps=300 q=-0.0 Lsize=  416227kB time=00:00:15.23 bitrate=223875.8kbits/s speed=12.5x

# %%
def encode_video(input_file, output_file, vcodec='libx265', resolution=None, preset=None, bitrate=None, crf=None):
    
    # delete folder is if exists, then create it
    output_folder, _ = output_file.rsplit('/', 1)
    if os.path.exists(output_folder):
        shutil.rmtree(output_folder)
    os.mkdir(output_folder)
    
    try:
        command = ['ffmpeg', '-y', '-i', input_file, '-c:v', vcodec]

        if resolution:
            resolution_str = f'{resolution[0]}:{resolution[1]}'
            command.extend(['-vf', f'scale={resolution_str}:force_original_aspect_ratio=increase,crop={resolution_str}'])

        if crf:
            command.extend(['-crf', crf, output_file])
        elif preset:
            command.extend(['-preset', preset, output_file])
        elif bitrate:
            command.extend(['-b:v', bitrate, output_file])
        
        subprocess.run(command)
        print("Video encoding successful!")
    except subprocess.CalledProcessError as e:
        print(f"Video encoding failed: {e}")

scene_number = 5
encoded_format = 'mp4'
resolution = (800, 600)
unprocessed_video_path = f'{video_folder}/scene_{scene_number}.{scene_format}'
video_folder = f'{video_folder}/scene_{scene_number}'
encoded_video_path = f'{video_folder}/encoded.{encoded_format}'

encode_video(
    unprocessed_video_path, 
    encoded_video_path, 
    vcodec = 'libx264', 
    resolution = resolution, 
    crf='0'
)

encoded_video_info = get_video_info(encoded_video_path)
encoded_video_info
# Out:
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-5)
#   configuration: --prefix=/home/itec/emanuele/.conda/envs/inpainting --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/pkg-config
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, avi, from 'Tears_of_Steel_1080p/scene_5.avi':
#   Metadata:
#     software        : Lavf60.16.100
#   Duration: 00:00:15.29, start: 0.000000, bitrate: 222979 kb/s
#   Stream #0:0: Video: huffyuv (HFYU / 0x55594648), yuv422p, 1920x800, 223443 kb/s, SAR 1:1 DAR 12:5, 24 fps, 24 tbr, 24 tbn
#   Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (huffyuv (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (mp3 (mp3float) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56475da64300] using SAR=1/1
# [libx264 @ 0x56475da64300] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x56475da64300] profile High 4:4:4 Predictive, level 3.1, 4:2:2, 8-bit
# [libx264 @ 0x56475da64300] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=0 mixed_ref=1 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=0 chroma_qp_offset=0 threads=19 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc=cqp mbtree=0 qp=0
# Output #0, mp4, to 'Tears_of_Steel_1080p/scene_5/encoded.mp4':
#   Metadata:
#     software        : Lavf60.16.100
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv422p(tv, progressive), 800x600 [SAR 1:1 DAR 4:3], q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       encoder         : Lavc60.31.102 aac
# frame=  324 fps= 79 q=0.0 size=   51456kB time=00:00:14.86 bitrate=28365.1kbits/s dup=1 drop=0 speed= 3.6x
# Video encoding successful!
# [out#0/mp4 @ 0x56475da79f40] video:58950kB audio:243kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.016966%
# frame=  367 fps= 79 q=-1.0 Lsize=   59203kB time=00:00:15.27 bitrate=31743.0kbits/s dup=1 drop=0 speed=3.29x
# [libx264 @ 0x56475da64300] frame I:2     Avg QP: 0.00  size:270590
# [libx264 @ 0x56475da64300] frame P:365   Avg QP: 0.00  size:163900
# [libx264 @ 0x56475da64300] mb I  I16..4: 23.1%  5.0% 71.8%
# [libx264 @ 0x56475da64300] mb P  I16..4:  2.2%  3.6%  6.0%  P16..4: 34.1% 23.4% 26.0%  0.0%  0.0%    skip: 4.6%
# [libx264 @ 0x56475da64300] 8x8 transform intra:29.4% inter:53.6%
# [libx264 @ 0x56475da64300] coded y,uvDC,uvAC intra: 97.0% 94.0% 93.9% inter: 90.1% 81.5% 81.2%
# [libx264 @ 0x56475da64300] i16 v,h,dc,p: 52% 47%  1%  0%
# [libx264 @ 0x56475da64300] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 54% 40%  2%  0%  1%  1%  1%  1%  1%
# [libx264 @ 0x56475da64300] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 44% 34%  4%  2%  4%  4%  3%  2%  2%
# [libx264 @ 0x56475da64300] i8c dc,h,v,p:  4% 17% 79%  0%
# [libx264 @ 0x56475da64300] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56475da64300] ref P L0: 72.3% 11.7% 12.3%  3.7%
# [libx264 @ 0x56475da64300] kb/s:31580.44
# [aac @ 0x56475df93cc0] Qavg: 705.382
# {'codec_name': 'h264',
#  'codec_tag_string': 'avc1',
#  'width': 800,
#  'height': 600,
#  'average_frame_rate': '24/1',
#  'duration': '15.291667',
#  'bit_rate': '31716185',
#  'bits_per_raw_sample': '8',
#  'encoder': None,
#  'file_name': 'Tears_of_Steel_1080p/scene_5/encoded.mp4',
#  'format_name': 'mov,mp4,m4a,3gp,3g2,mj2',
#  'size': '60624169'}

# %%
def split_video_into_frames(video_path: str, frames_folder: str) -> str:
    
    # delete folder is if exists, then create it
    if os.path.exists(frames_folder):
        shutil.rmtree(frames_folder)
    os.mkdir(frames_folder)

    subprocess.run(f'ffmpeg -i {video_path} {frames_folder}/frame%04d.png', shell=True)
    return frames_folder

def split_image_into_squares(image: np.array, l: int) -> np.array:
    """
    Split an image into squares of a specific size.

    Args:
    - image: numpy array representing the image with shape [n, m, c]
    - l: integer representing the side length of each square

    Returns:
    - numpy array with shape [n//l, m//l, l, l, c] containing the squares
    """
    n, m, c = image.shape
    num_rows = n // l
    num_cols = m // l
    squares = np.zeros((num_rows, num_cols, l, l, c), dtype=image.dtype)
    for i in range(num_rows):
        for j in range(num_cols):
            squares[i, j] = image[i*l:(i+1)*l, j*l:(j+1)*l, :]
    return squares

def filter_squares(squares: np.array, filter_factor: int, inpaint_white: bool = True) -> Union[np.array, np.array]:
    """
    Filter squares based on their indices.

    Args:
    - squares: numpy array with shape [n, m, l, l, c] containing the squares

    Returns:
    - filtered_squares: numpy array with shape [n_filtered, m_filtered, l, l, c] containing the filtered squares
    - filter_mask: numpy array with shape [n, m] indicating which blocks were kept (1) or filtered out (0)
    """
    n, m, _, _, _ = squares.shape
    if inpaint_white:
        filter_mask = np.ones(squares.shape, dtype=int) * 255
        filter_mask[::filter_factor, ::filter_factor] = 0
    else:
        filter_mask = np.zeros(squares.shape, dtype=int)
        filter_mask[::filter_factor, ::filter_factor] = 255

    filtered_squares = squares[::filter_factor, ::filter_factor]

    return filtered_squares, filter_mask

def flatten_squares_into_image(squares: np.array) -> np.array:
    """
    Reconstruct the original image from split squares.

    Args:
    - squares: numpy array with shape [n, m, l, l, c] containing the split squares

    Returns:
    - numpy array representing the reconstructed image
    """
    n, m, l, _, c = squares.shape
    num_rows = n * l
    num_cols = m * l
    image = np.zeros((num_rows, num_cols, c), dtype=squares.dtype)
    for i in range(n):
        for j in range(m):
            image[i*l:(i+1)*l, j*l:(j+1)*l, :] = squares[i, j]
    return image

def save_image(frame: np.array, output_folder: str, file_name: str) -> None:

    # Create the output directory if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)
    # save filtered frame, overwrite if it exists
    cv2.imwrite(output_folder + '/' + file_name, frame, [int(cv2.IMWRITE_PNG_COMPRESSION), 0])

def process_frame_server_side(frame_name, frames_folder, square_size, filter_factor):
    frame = cv2.imread(frames_folder + '/' + frame_name)
    squared_frame = split_image_into_squares(frame, square_size)
    filtered_squares, mask_squares = filter_squares(squared_frame, filter_factor)
    filtered_flattened = flatten_squares_into_image(filtered_squares)
    mask_flattened = flatten_squares_into_image(mask_squares)
    parent_folder, _ = frames_folder.rsplit('/', 1)
    save_image(filtered_flattened, parent_folder + '/' + 'shrunk', frame_name)
    save_image(mask_flattened, parent_folder + '/' + 'masks', frame_name)
    return frame_name

def process_frames_in_parallel(frames_folder, processing_function, num_processes, **kwargs):
    frame_names = [frame_name for frame_name in os.listdir(frames_folder) if frame_name.endswith('.png')]
    
    with ProcessPoolExecutor(max_workers=num_processes) as executor:
        results = []
        for frame_name in frame_names:
            results.append(executor.submit(processing_function, frame_name, frames_folder, **kwargs))
        
        # Retrieve results
        processed_frame_names = [future.result() for future in results]

    return processed_frame_names

def reconstruct_video_from_frames(frames_folder, output_video_path, frame_rate=30):

    # If the video file exists, delete it
    if os.path.exists(output_video_path):
        os.remove(output_video_path)

    # Construct ffmpeg command
    cmd = ['ffmpeg', '-framerate', str(frame_rate), '-pattern_type', 'glob', '-i', f'{frames_folder}/*.png',
                  '-c:v', 'libx264', '-pix_fmt', 'yuv420p', output_video_path]

    # Run ffmpeg command
    subprocess.run(cmd)

encoded_frames_folder, _ = encoded_video_path.rsplit('.', 1)
split_video_into_frames(encoded_video_path, encoded_frames_folder)
square_size = 20
filter_factor = 2
num_processes = 16
processed_frame_names = process_frames_in_parallel(
    encoded_frames_folder, 
    process_frame_server_side, 
    num_processes,
    square_size=square_size, 
    filter_factor=filter_factor
)
frame_rate = eval(unprocessed_video_info['average_frame_rate'])
reconstruct_video_from_frames(video_folder + '/shrunk', video_folder + '/shrunk.mp4', frame_rate)
# Out:
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-5)
#   configuration: --prefix=/home/itec/emanuele/.conda/envs/inpainting --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/pkg-config
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'Tears_of_Steel_1080p/scene_5/encoded.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:15.29, start: 0.000000, bitrate: 31716 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv422p(progressive), 800x600 [SAR 1:1 DAR 4:3], 31580 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 129 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'Tears_of_Steel_1080p/scene_5/encoded/frame%04d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 800x600 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 24 fps, 24 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 png
# [out#0/image2 @ 0x560b529d4740] video:321101kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=  367 fps=308 q=-0.0 Lsize=N/A time=00:00:15.25 bitrate=N/A speed=12.8x
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-5)
#   configuration: --prefix=/home/itec/emanuele/.conda/envs/inpainting --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/pkg-config
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, image2, from 'Tears_of_Steel_1080p/scene_5/shrunk/*.png':
#   Duration: 00:00:15.29, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown), 400x300, 24 fps, 24 tbr, 24 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x559afe0dc700] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x559afe0dc700] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x559afe0dc700] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=9 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'Tears_of_Steel_1080p/scene_5/shrunk.mp4':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 400x300, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x559afe0d94c0] video:786kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.608431%
# frame=  367 fps=0.0 q=-1.0 Lsize=     791kB time=00:00:15.16 bitrate= 427.4kbits/s speed=17.3x
# [libx264 @ 0x559afe0dc700] frame I:2     Avg QP:22.91  size: 14516
# [libx264 @ 0x559afe0dc700] frame P:152   Avg QP:24.83  size:  3805
# [libx264 @ 0x559afe0dc700] frame B:213   Avg QP:29.93  size:   926
# [libx264 @ 0x559afe0dc700] consecutive B-frames: 17.7% 13.1%  4.9% 64.3%
# [libx264 @ 0x559afe0dc700] mb I  I16..4:  1.7% 44.7% 53.6%
# [libx264 @ 0x559afe0dc700] mb P  I16..4:  0.2%  1.5%  2.2%  P16..4: 27.6% 29.3% 18.6%  0.0%  0.0%    skip:20.6%
# [libx264 @ 0x559afe0dc700] mb B  I16..4:  0.0%  0.1%  0.4%  B16..8: 20.6%  9.5%  3.6%  direct: 2.8%  skip:62.9%  L0:33.4% L1:53.9% BI:12.7%
# [libx264 @ 0x559afe0dc700] 8x8 transform intra:38.0% inter:46.4%
# [libx264 @ 0x559afe0dc700] coded y,uvDC,uvAC intra: 89.2% 83.0% 56.0% inter: 19.2% 10.9% 1.8%
# [libx264 @ 0x559afe0dc700] i16 v,h,dc,p: 51% 10% 16% 24%
# [libx264 @ 0x559afe0dc700] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 14% 15%  8%  7%  8%  7%  9% 14%
# [libx264 @ 0x559afe0dc700] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 20% 13%  7%  7%  8%  7%  7%  8%
# [libx264 @ 0x559afe0dc700] i8c dc,h,v,p: 49% 18% 26%  7%
# [libx264 @ 0x559afe0dc700] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x559afe0dc700] ref P L0: 71.8% 17.3%  7.9%  3.0%
# [libx264 @ 0x559afe0dc700] ref B L0: 93.9%  4.5%  1.6%
# [libx264 @ 0x559afe0dc700] ref B L1: 98.0%  2.0%
# [libx264 @ 0x559afe0dc700] kb/s:420.97

# %%
def encode_video(input_video_path: str, output_video_path: str, codec: str, bitrate: str = None, crf: int = None) -> Union[str, None]:
    """
    Encode a video file with the specified codec and bitrate.

    Args:
    - input_video_path: Path to the input video file.
    - output_video_path: Path to save the output video.
    - codec: Codec to use for encoding (default: libx264).
    - bitrate: Bitrate for the output video (default: '10M' for 10 Mbps).

    Returns:
    - A warning string if the parameters are not correctly selected
    - None otherwise
    """

    # If the video file exists, delete it
    if os.path.exists(output_video_path):
        os.remove(output_video_path)
    
    if bitrate:
        command = ['ffmpeg', '-y', '-i', input_video_path, '-c:v', codec, '-b:v', bitrate, output_video_path]
    elif crf:
        command = ['ffmpeg', '-y', '-i', input_video_path, '-c:v', codec, '-crf', str(crf), output_video_path]
    else:
        return 'Please specify either a target bitrate or a compression rate factor'
    subprocess.run(command)

def calculate_mse(img1, img2):
    err = np.sum((img1.astype("float") - img2.astype("float")) ** 2)
    err /= float(img1.shape[0] * img1.shape[1])
    return err

def calculate_psnr(img1, img2):
    mse = calculate_mse(img1, img2)
    if mse == 0:
        return float('inf')
    PIXEL_MAX = 255.0
    return 20 * np.log10(PIXEL_MAX / np.sqrt(mse))

def calculate_ssim(img1, img2):
    img1_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    img2_gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
    return ssim(img1_gray, img2_gray)

def calculate_vmaf(distorted_video_path, original_video_path, model_path):
    command = [
        'ffmpeg',
        '-i', distorted_video_path,
        '-i', original_video_path,
        '-filter_complex libvmaf -f null -'
    ]
    result = subprocess.run(' '.join(command), shell=True, capture_output=True, text=True)
    print(result)
    output = result.stdout
    print(output)
    vmaf_score = json.loads(output)['aggregate']['VMAF_score']
    return vmaf_score

def compare_videos(video1_path, video2_path, model_path):
    cap1 = cv2.VideoCapture(video1_path)
    cap2 = cv2.VideoCapture(video2_path)
    frame_count = min(int(cap1.get(cv2.CAP_PROP_FRAME_COUNT)), int(cap2.get(cv2.CAP_PROP_FRAME_COUNT)))
    mse_total = 0
    psnr_total = 0
    ssim_total = 0
    # vmaf_score = calculate_vmaf(video1_path, video2_path, model_path)
    vmaf_score = 0
    for _ in range(frame_count):
        ret1, frame1 = cap1.read()
        ret2, frame2 = cap2.read()
        if not (ret1 and ret2):
            break
        mse_total += calculate_mse(frame1, frame2)
        psnr_total += calculate_psnr(frame1, frame2)
        ssim_total += calculate_ssim(frame1, frame2)
    cap1.release()
    cap2.release()
    mse_avg = mse_total / frame_count
    psnr_avg = psnr_total / frame_count
    ssim_avg = ssim_total / frame_count
    return mse_avg, psnr_avg, ssim_avg, vmaf_score

# %%
# CLIENT SIDE

def stretch_frame(frame: np.array, mask: np.array, filter_factor: int) -> np.array:
    
    '''
    Arguments:
    - frame: numpy array with shape [n, m, l, l, c] containing the squares
    - mask: numpy array with shape [N, M, l, l, c] containing [n//l, m//l] white squares and [N - n//l, M - m//l] black squares
    - l: an integer specifying the side in pixel of a square

    Returns:
    - stretched_frame: numpy array with shape [N, M, l, l, c] where the squares of frame are substituted to the white squares of mask
    '''

    # Get dimensions
    n, m, _, _, _ = frame.shape
    N, _, _, _, _ = mask.shape

    stretched_frame = np.copy(mask)

    for i in range(n):
        for j in range(m):
            # iterate through each frame block
            frame_block = frame[i, j, :, :, :]
            # put it into the corresponding mask white block by multiplying its indices by the filter factor
            stretched_frame[int(i * filter_factor), int(j * filter_factor), :, :, :] = frame_block
    return stretched_frame

def process_frame_client_side(frame_name, frames_folder, square_size, mask_squares, filter_factor):
    frame = cv2.imread(frames_folder + '/' + frame_name)
    squares = split_image_into_squares(frame, square_size)
    stretched_squares = stretch_frame(squares, mask_squares, filter_factor)
    stretched_flattened = flatten_squares_into_image(stretched_squares)
    parent_folder, _ = frames_folder.rsplit('/', 1)
    save_image(stretched_flattened, parent_folder + '/stretched', frame_name)
    return frame_name

square_size = 20
filter_factor = 2
num_processes = 16

# TODO: now we're passing a predetermined mask, needs a function that takes as input one or more masks, 
# and yields one mask after another then loops back from the first, each time it's called
mask_frame_path = video_folder + '/masks/frame0001.png'
mask_frame = cv2.imread(mask_frame_path)
mask_squares = split_image_into_squares(mask_frame, square_size)
shrunk_frames_folder = video_folder + '/shrunk'
processed_frame_names = process_frames_in_parallel(
    shrunk_frames_folder, 
    process_frame_client_side, 
    num_processes,
    square_size=square_size, 
    mask_squares=mask_squares, 
    filter_factor=filter_factor
)
reconstruct_video_from_frames(video_folder + '/stretched', video_folder + '/stretched.mp4', frame_rate)
# Out:
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-5)
#   configuration: --prefix=/home/itec/emanuele/.conda/envs/inpainting --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1706918361713/_build_env/bin/pkg-config
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, image2, from 'Tears_of_Steel_1080p/scene_5/stretched/*.png':
#   Duration: 00:00:15.29, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown), 800x600, 24 fps, 24 tbr, 24 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5652961611c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5652961611c0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5652961611c0] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=19 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'Tears_of_Steel_1080p/scene_5/stretched.mp4':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 800x600, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x565296155dc0] video:1042kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.420192%
# frame=  367 fps=360 q=-1.0 Lsize=    1046kB time=00:00:15.16 bitrate= 565.2kbits/s speed=14.9x
# [libx264 @ 0x5652961611c0] frame I:2     Avg QP:20.23  size: 22204
# [libx264 @ 0x5652961611c0] frame P:189   Avg QP:23.89  size:  4464
# [libx264 @ 0x5652961611c0] frame B:176   Avg QP:27.93  size:  1014
# [libx264 @ 0x5652961611c0] consecutive B-frames: 33.5%  6.0%  4.9% 55.6%
# [libx264 @ 0x5652961611c0] mb I  I16..4:  1.0% 48.7% 50.3%
# [libx264 @ 0x5652961611c0] mb P  I16..4:  0.6%  2.7%  0.6%  P16..4: 14.1% 10.1%  5.6%  0.0%  0.0%    skip:66.3%
# [libx264 @ 0x5652961611c0] mb B  I16..4:  0.4%  0.5%  0.1%  B16..8: 10.6%  2.9%  0.6%  direct: 1.4%  skip:83.5%  L0:42.2% L1:52.5% BI: 5.3%
# [libx264 @ 0x5652961611c0] 8x8 transform intra:62.6% inter:38.8%
# [libx264 @ 0x5652961611c0] coded y,uvDC,uvAC intra: 13.0% 32.3% 19.9% inter: 6.1% 3.3% 0.9%
# [libx264 @ 0x5652961611c0] i16 v,h,dc,p: 60% 32%  8%  0%
# [libx264 @ 0x5652961611c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 10% 69%  1%  0%  0%  0%  0%  1%
# [libx264 @ 0x5652961611c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 48% 23% 13%  3%  2%  3%  2%  2%  4%
# [libx264 @ 0x5652961611c0] i8c dc,h,v,p: 34% 23% 44%  0%
# [libx264 @ 0x5652961611c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5652961611c0] ref P L0: 84.9%  5.5%  5.8%  3.8%
# [libx264 @ 0x5652961611c0] ref B L0: 78.9% 15.8%  5.2%
# [libx264 @ 0x5652961611c0] ref B L1: 97.0%  3.0%
# [libx264 @ 0x5652961611c0] kb/s:557.92

# %%
# inpaint with ProPainter

# def inpaint_with_Propainter(
#         input_path: str, 
#         mask_path: str, 
#         neighbor_length: int = 10, 
#         ref_stride: int = 10, 
#         resize_ratio: float = 1.0, 
#         output_height: int = None, 
#         output_width: int = None
# )

propainter_input_video = scene_name + 'stretched.mp4'
propainter_input_mask = mask_frame_path
# TODO: make into function with optional parameters mentioned in repo readme
cmd = f'python inference_propainter.py --video {propainter_input_video} --mask {propainter_input_mask} --height {height} --width {width}'

# compare inpainting with original

# Compare videos
inpainted = '/home/itec/emanuele/ProPainter/results/stretched/inpaint_out.mp4'
# TODO: instead of inpainting from original, we need to inpaint from the encoded version the client receives to be precise
original = '/home/itec/emanuele/ProPainter/inputs/video_completion/stretched.mp4'
model_path = '/home/shared/athena/vmaf/model/vmaf_v0.6.1.pkl'
mse_avg, psnr_avg, ssim_avg, vmaf_score = compare_videos(original, inpainted, model_path)
print("Average MSE:", mse_avg)
print("Average PSNR:", psnr_avg)
print("Average SSIM:", ssim_avg)
print("VMAF Score:", vmaf_score) # TODO: vmaf still does not work

# TODO: either merge the requirements of each inpainting model, or move this code to a script 
#       so that the environment can be changed during execution (probably a mess to implement)

# TODO: fix the results of this model, reimplement old one, find new ones, especially for video inpainting.

# TODO: develop a model that trains on videos with masked portions, and outputs the goodness of fit to the original. 
#       So it learns to recognize which masks would allow a certain video to be inpainted with minimal error.
#       The step further would be to have another model training on videos, and outputting the best mask for them.

# TODO: find or create metric that measures how "generated" an image or video looks. 
#       It should realize which artefacts are typical of GenAI and penalize them, or in a simpler form, 
#       penalize also cartoons and such, but then it can only be applied to real videos.

# TODO: we can use animation videos to improve quality and train our own network with only a few animation videos 
#       to showcase the potential of the approach, and then say that a bigger, more general model can reach this results on any video

# TODO: I don't like having functions that return nothing. Can they be included in other functions, or written outside of a function?

# TODO: recognize objects, generate masks that follow them, attribute a fidelity coefficient to each object, 
#       inpaint each object at different qualities, based on their fidelity coefficients. 
#       To do this with current model, inpaint the video once per object, then patch together all inpaintings. 
#       This is slow, but will offer the same result as a single, multi-inpainting model.

# TODO: split into blocks, calculate quality of each block against the uncompressed, average them

# TODO: multithread the processing to speed up
